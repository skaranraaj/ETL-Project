# %% [markdown]
# Silver Layer 🥈

# %% [markdown]
# Imports

# %%
import pandas as pd 
import numpy as np 
import string
import datetime

# %% [markdown]
# Load the Bronze layer data

# %%
df=pd.read_parquet('./Bronze layer/Bronze.parquet')

# %% [markdown]
# Generalized Data Validation and Cleaning functions

# %%
def drop_null_columns(df, threshold=0.2):
    '''dropping columns with null values more than the threshold value'''
    null_percentage = df.isnull().mean()
    columns_to_keep= null_percentage[null_percentage<threshold].index 
    
    if len(columns_to_keep)==len(df.columns):
        print("No columns removed")
    else:
        print(f"Removing: {[c for c in df.columns if c not in columns_to_keep]}")
    return df[columns_to_keep]

# %%
def fill_missing_values(df,columns_defaults:dict):
    '''filling missing values in the columns'''
    for column,default_value in columns_defaults.items():
        df[column] = df[column].fillna(default_value)
    return df

# %%
def convert_column_types(df,column_types:dict):
    '''converting the columns to the desired datatype'''
    try:
        for column,dtype in column_types.items():
               df[column] = df[column].astype(dtype)
        return df
    except Exception as e:
         print(f"{column} caused an issue")
         raise e

# %%
def remove_punctuation(df, columns:list):
    '''removing punctuations from the columns'''
    for c in columns:
        df.loc[:,c] = df[c].str.replace(r'[^\w\s]|_','',regex=True)
    return df

# %%
def check_formats(df, expected_formats: dict):
    '''checking formats of the columns'''
    incorrect_formats =[]
    for column,datatype in df.dtypes.to_dict().items():
        expected_type = expected_formats.get(column)
        if expected_type != datatype:
            incorrect_formats.append((column,datatype,expected_type))
    
    incorrect_columns =[c[0] for c in incorrect_formats]
    correct_format_count = len([c for c in df.columns if c not in incorrect_columns])
    if incorrect_formats:
        print('Below are incorrect formats')
        print('_'*50)
        print(f"Correct column count: {correct_format_count}")
        return pd.DataFrame(incorrect_formats, columns=['Columns','Actual','Expected'])
    else:
        print("Validation Complete, no discrepancies")

# %%
def check_similarity(word1:str,word2:str)->float:
    '''checking similarity between two words'''
    word_set1=set(word1)
    word_set2=set(word2)

    intersection = word_set1.intersection(word_set2)
    intersection_count=len(intersection)

    total_char_count = len(word_set1.union(word_set2))

    similarity=intersection_count/total_char_count
    return similarity

# %%
def check_mispelling(dataframe: pd.DataFrame, column: str, similarity_threshold: float)->pd.DataFrame:
    '''checking for mispellings of words'''
    all_unique_values = list(set(dataframe[column].tolist()))

    similarity_list=[]

    for n in range(len(all_unique_values)):
        value1=all_unique_values[n]
        for n2 in range(n+1,len(all_unique_values)):
            value2=all_unique_values[n2]
            similarity= round(check_similarity(value1,value2),4)
            if similarity >=similarity_threshold:
                similarity_list.append([value1,value2,similarity])
    return pd.DataFrame(similarity_list,columns=['name1','name2','similarity'])

# %% [markdown]
# Apply Validations and Cleaning

# %%
df.head()
# Out:
#   Player Name          Team             World     Vehicle Type     Companion  \
# 0       Yoshi  Toad Brigade    Yoshi's Island       Comet Bike     pOLTERPUP
# 1      PeachK    GREEN CAPS      Donut Plains  Circuit Special  kOOPA tROOPA
# 2     Waluigi          None    Yoshi's Island       Biddybuggy        Goomba
# 3       Yoshi  Toad Brigade        Star World       Pipe Frame        Goomba
# 4  Bowser Jr.    Koopa Clan  Mushroom Kingdom       Pipe Frame          tOAD
#
#   Kart Racing Rank Platforming Rank Boss Battle Rank  Power-Ups Used  \
# 0                A                A                A              12
# 1                C                A                B              16
# 2                D                A                C              26
# 3                C                D                A              23
# 4                C                C                B              10
#
#   Kart Role  ...  Lives Lost  Participation in Battle Mode  \
# 0   Drifter  ...         0.0                           Yes
# 1   Drifter  ...         4.0                            No
# 2   Blocker  ...         1.0                            No
# 3   Drifter  ...         5.0                            No
# 4   Blocker  ...         2.0                           Yes
#
#   Mushroom Cup Participation                      Power-Ups Owned  \
# 0                         No                        1-Up Mushroom
# 1                         No                Red Shell, Super Star
# 2                        Yes                          Green Shell
# 3                        Yes                        1-Up Mushroom
# 4                         No  Red Shell, Banana Peel, Fire Flower
#
#   Coins Spent in Toad Town  Levels Completed  Times Hit by Enemies  \
# 0                       64                26                  4.26
# 1                      335                40                  5.00
# 2                      182                57                  5.50
# 3                      333                84                  6.00
# 4                      461                55                  7.00
#
#                           Primary Game                 filename  \
# 0           Mario Tennis Aces           mario_data_20250101.csv
# 1                    Mario Tennis Aces  mario_data_20250101.csv
# 2                  Mario Kart 8 Deluxe  mario_data_20250101.csv
# 3                    Super Mario Bros.  mario_data_20250101.csv
# 4                    Super Mario World  mario_data_20250101.csv
#
#            loadDateTimeStamp
# 0 2025-10-28 15:21:26.079051
# 1 2025-10-28 15:21:26.079051
# 2 2025-10-28 15:21:26.079051
# 3 2025-10-28 15:21:26.079051
# 4 2025-10-28 15:21:26.079051
#
# [5 rows x 21 columns]

# %%
# checking the number of null values
df.isnull().sum()
# Out:
# Player Name                      9040
# Team                             2960
# World                               0
# Vehicle Type                        0
# Companion                           0
# Kart Racing Rank                 9280
# Platforming Rank                    0
# Boss Battle Rank                    0
# Power-Ups Used                      0
# Kart Role                           0
# Team Points                         0
# Lives Lost                          0
# Participation in Battle Mode        0
# Mushroom Cup Participation      12400
# Power-Ups Owned                     0
# Coins Spent in Toad Town            0
# Levels Completed                    0
# Times Hit by Enemies                0
# Primary Game                        0
# filename                            0
# loadDateTimeStamp                   0
# dtype: int64

# %%
# checking percentage of null values within each column
df.isnull().mean()*100
# Out:
# Player Name                     18.833333
# Team                             6.166667
# World                            0.000000
# Vehicle Type                     0.000000
# Companion                        0.000000
# Kart Racing Rank                19.333333
# Platforming Rank                 0.000000
# Boss Battle Rank                 0.000000
# Power-Ups Used                   0.000000
# Kart Role                        0.000000
# Team Points                      0.000000
# Lives Lost                       0.000000
# Participation in Battle Mode     0.000000
# Mushroom Cup Participation      25.833333
# Power-Ups Owned                  0.000000
# Coins Spent in Toad Town         0.000000
# Levels Completed                 0.000000
# Times Hit by Enemies             0.000000
# Primary Game                     0.000000
# filename                         0.000000
# loadDateTimeStamp                0.000000
# dtype: float64

# %%
# checking the columns that have null values greater than threshold
drop_null_columns(df,threshold=0.2)
# Out:
# Removing: ['Mushroom Cup Participation']
#       Player Name          Team             World     Vehicle Type  \
# 0           Yoshi  Toad Brigade    Yoshi's Island       Comet Bike
# 1          PeachK    GREEN CAPS      Donut Plains  Circuit Special
# 2         Waluigi          None    Yoshi's Island       Biddybuggy
# 3           Yoshi  Toad Brigade        Star World       Pipe Frame
# 4      Bowser Jr.    Koopa Clan  Mushroom Kingdom       Pipe Frame
# ...           ...           ...               ...              ...
# 47995    Toadette    Green Caps        Star World           Mach 8
# 47996  Bowser Jr.  Dino Buddies      Donut Plains  Circuit Special
# 47997       Luigi    Green Caps      dONUT pLAINS       Biddybuggy
# 47998    Toadette    Koopa Clan  mUSHROOM kINGDOM  Circuit Special
# 47999    Rosalina  Toad Brigade     Koopa Kingdom           Mach 8
#
#           Companion Kart Racing Rank Platforming Rank Boss Battle Rank  \
# 0         pOLTERPUP                A                A                A
# 1      kOOPA tROOPA                C                A                B
# 2            Goomba                D                A                C
# 3            Goomba                C                D                A
# 4              tOAD                C                C                B
# ...             ...              ...              ...              ...
# 47995          Luma                B                A                S
# 47996  Koopa Troopa                C                C                B
# 47997       Shy Guy                A                D                D
# 47998         Yoshi                B                A                B
# 47999     Polterpup                B                C                C
#
#        Power-Ups Used        Kart Role  Team Points  Lives Lost  \
# 0                  12          Drifter        -34.0    0.000000
# 1                  16          Drifter        149.0    4.000000
# 2                  26          Blocker        174.0    1.000000
# 3                  23          Drifter         -1.0    5.000000
# 4                  10          Blocker         28.0    2.000000
# ...               ...              ...          ...         ...
# 47995               8          Drifter        -84.0    0.000000
# 47996              13        Speedster        110.0    1.083565
# 47997              27          Drifter        -38.0    4.000000
# 47998               8  Item Specialist        111.0    0.000000
# 47999               8          Drifter        175.0    2.000000
#
#       Participation in Battle Mode                         Power-Ups Owned  \
# 0                              Yes                           1-Up Mushroom
# 1                               No                   Red Shell, Super Star
# 2                               No                             Green Shell
# 3                               No                           1-Up Mushroom
# 4                              Yes     Red Shell, Banana Peel, Fire Flower
# ...                            ...                                     ...
# 47995                           No           1-Up Mushroom, Super Mushroom
# 47996                           No                             Fire Flower
# 47997                          Yes                              Super Star
# 47998                          Yes    Super Star, Banana Peel, Green Shell
# 47999                          Yes  Super Star, Fire Flower, 1-Up Mushroom
#
#        Coins Spent in Toad Town  Levels Completed  Times Hit by Enemies  \
# 0                            64                26                  4.26
# 1                           335                40                  5.00
# 2                           182                57                  5.50
# 3                           333                84                  6.00
# 4                           461                55                  7.00
# ...                         ...               ...                   ...
# 47995                       172                43                  5.00
# 47996                        11                72                  9.00
# 47997                       460                25                  2.00
# 47998                        82                39                  4.00
# 47999                       178                74                  1.00
#
#                                          Primary Game  \
# 0                          Mario Tennis Aces
# 1                                   Mario Tennis Aces
# 2                                 Mario Kart 8 Deluxe
# 3                                   Super Mario Bros.
# 4                                   Super Mario World
# ...                                               ...
# 47995                               Super Mario Bros.
# 47996                               Super Mario World
# 47997                             Super Mario Odyssey
# 47998                    Mario Kart 8 Deluxe
# 47999                          Mario Party Superstars
#
#                         filename          loadDateTimeStamp
# 0        mario_data_20250101.csv 2025-10-28 15:21:26.079051
# 1        mario_data_20250101.csv 2025-10-28 15:21:26.079051
# 2        mario_data_20250101.csv 2025-10-28 15:21:26.079051
# 3        mario_data_20250101.csv 2025-10-28 15:21:26.079051
# 4        mario_data_20250101.csv 2025-10-28 15:21:26.079051
# ...                          ...                        ...
# 47995  mario_data_20250601.jsonl 2025-10-28 15:21:27.251040
# 47996  mario_data_20250601.jsonl 2025-10-28 15:21:27.251040
# 47997  mario_data_20250601.jsonl 2025-10-28 15:21:27.251040
# 47998  mario_data_20250601.jsonl 2025-10-28 15:21:27.251040
# 47999  mario_data_20250601.jsonl 2025-10-28 15:21:27.251040
#
# [48000 rows x 20 columns]

# %%
# checking the data
df.head()
# Out:
#   Player Name          Team             World     Vehicle Type     Companion  \
# 0       Yoshi  Toad Brigade    Yoshi's Island       Comet Bike     pOLTERPUP
# 1      PeachK    GREEN CAPS      Donut Plains  Circuit Special  kOOPA tROOPA
# 2     Waluigi          None    Yoshi's Island       Biddybuggy        Goomba
# 3       Yoshi  Toad Brigade        Star World       Pipe Frame        Goomba
# 4  Bowser Jr.    Koopa Clan  Mushroom Kingdom       Pipe Frame          tOAD
#
#   Kart Racing Rank Platforming Rank Boss Battle Rank  Power-Ups Used  \
# 0                A                A                A              12
# 1                C                A                B              16
# 2                D                A                C              26
# 3                C                D                A              23
# 4                C                C                B              10
#
#   Kart Role  ...  Lives Lost  Participation in Battle Mode  \
# 0   Drifter  ...         0.0                           Yes
# 1   Drifter  ...         4.0                            No
# 2   Blocker  ...         1.0                            No
# 3   Drifter  ...         5.0                            No
# 4   Blocker  ...         2.0                           Yes
#
#   Mushroom Cup Participation                      Power-Ups Owned  \
# 0                         No                        1-Up Mushroom
# 1                         No                Red Shell, Super Star
# 2                        Yes                          Green Shell
# 3                        Yes                        1-Up Mushroom
# 4                         No  Red Shell, Banana Peel, Fire Flower
#
#   Coins Spent in Toad Town  Levels Completed  Times Hit by Enemies  \
# 0                       64                26                  4.26
# 1                      335                40                  5.00
# 2                      182                57                  5.50
# 3                      333                84                  6.00
# 4                      461                55                  7.00
#
#                           Primary Game                 filename  \
# 0           Mario Tennis Aces           mario_data_20250101.csv
# 1                    Mario Tennis Aces  mario_data_20250101.csv
# 2                  Mario Kart 8 Deluxe  mario_data_20250101.csv
# 3                    Super Mario Bros.  mario_data_20250101.csv
# 4                    Super Mario World  mario_data_20250101.csv
#
#            loadDateTimeStamp
# 0 2025-10-28 15:21:26.079051
# 1 2025-10-28 15:21:26.079051
# 2 2025-10-28 15:21:26.079051
# 3 2025-10-28 15:21:26.079051
# 4 2025-10-28 15:21:26.079051
#
# [5 rows x 21 columns]

# %%
# checking the minimum value of power-ups used to assign a missing value in next step
min(df['Power-Ups Used'])
# Out:
# 5

# %%
# filling null values in each column with a default value
fill_missing_values(df,{'Player Name':'Unknown Player', 'Team':'Unknown Team','World':'Unknown World','Vehicle Type': 'Unknown Vehicle','Companion':'Unkown Companion','Kart Racing Rank':'Unkown Rank','Platforming Rank':'Unkown Rank','Boss Battle Rank':'Unkown Rank','Power-Ups Used':0,'Kart Role':'Unkown Role','Team Points':0.0,'Lives Lost':0.0,'Participation in Battle Mode':'Unkown','Mushroom Cup Participation':'Unkown','Power-Ups Owned':'None','Coins Spent in Toad Town':0,'Levels Completed':0,'Times Hit by Enemies':0.0,'Primary Game':'N/A'})
# Out:
#       Player Name          Team             World     Vehicle Type  \
# 0           Yoshi  Toad Brigade    Yoshi's Island       Comet Bike
# 1          PeachK    GREEN CAPS      Donut Plains  Circuit Special
# 2         Waluigi  Unknown Team    Yoshi's Island       Biddybuggy
# 3           Yoshi  Toad Brigade        Star World       Pipe Frame
# 4      Bowser Jr.    Koopa Clan  Mushroom Kingdom       Pipe Frame
# ...           ...           ...               ...              ...
# 47995    Toadette    Green Caps        Star World           Mach 8
# 47996  Bowser Jr.  Dino Buddies      Donut Plains  Circuit Special
# 47997       Luigi    Green Caps      dONUT pLAINS       Biddybuggy
# 47998    Toadette    Koopa Clan  mUSHROOM kINGDOM  Circuit Special
# 47999    Rosalina  Toad Brigade     Koopa Kingdom           Mach 8
#
#           Companion Kart Racing Rank Platforming Rank Boss Battle Rank  \
# 0         pOLTERPUP                A                A                A
# 1      kOOPA tROOPA                C                A                B
# 2            Goomba                D                A                C
# 3            Goomba                C                D                A
# 4              tOAD                C                C                B
# ...             ...              ...              ...              ...
# 47995          Luma                B                A                S
# 47996  Koopa Troopa                C                C                B
# 47997       Shy Guy                A                D                D
# 47998         Yoshi                B                A                B
# 47999     Polterpup                B                C                C
#
#        Power-Ups Used        Kart Role  ...  Lives Lost  \
# 0                  12          Drifter  ...    0.000000
# 1                  16          Drifter  ...    4.000000
# 2                  26          Blocker  ...    1.000000
# 3                  23          Drifter  ...    5.000000
# 4                  10          Blocker  ...    2.000000
# ...               ...              ...  ...         ...
# 47995               8          Drifter  ...    0.000000
# 47996              13        Speedster  ...    1.083565
# 47997              27          Drifter  ...    4.000000
# 47998               8  Item Specialist  ...    0.000000
# 47999               8          Drifter  ...    2.000000
#
#        Participation in Battle Mode Mushroom Cup Participation  \
# 0                               Yes                         No
# 1                                No                         No
# 2                                No                        Yes
# 3                                No                        Yes
# 4                               Yes                         No
# ...                             ...                        ...
# 47995                            No                        Yes
# 47996                            No                     Unkown
# 47997                           Yes                     Unkown
# 47998                           Yes                        Yes
# 47999                           Yes                         No
#
#                               Power-Ups Owned Coins Spent in Toad Town  \
# 0                               1-Up Mushroom                       64
# 1                       Red Shell, Super Star                      335
# 2                                 Green Shell                      182
# 3                               1-Up Mushroom                      333
# 4         Red Shell, Banana Peel, Fire Flower                      461
# ...                                       ...                      ...
# 47995           1-Up Mushroom, Super Mushroom                      172
# 47996                             Fire Flower                       11
# 47997                              Super Star                      460
# 47998    Super Star, Banana Peel, Green Shell                       82
# 47999  Super Star, Fire Flower, 1-Up Mushroom                      178
#
#        Levels Completed  Times Hit by Enemies  \
# 0                    26                  4.26
# 1                    40                  5.00
# 2                    57                  5.50
# 3                    84                  6.00
# 4                    55                  7.00
# ...                 ...                   ...
# 47995                43                  5.00
# 47996                72                  9.00
# 47997                25                  2.00
# 47998                39                  4.00
# 47999                74                  1.00
#
#                                          Primary Game  \
# 0                          Mario Tennis Aces
# 1                                   Mario Tennis Aces
# 2                                 Mario Kart 8 Deluxe
# 3                                   Super Mario Bros.
# 4                                   Super Mario World
# ...                                               ...
# 47995                               Super Mario Bros.
# 47996                               Super Mario World
# 47997                             Super Mario Odyssey
# 47998                    Mario Kart 8 Deluxe
# 47999                          Mario Party Superstars
#
#                         filename          loadDateTimeStamp
# 0        mario_data_20250101.csv 2025-10-28 15:21:26.079051
# 1        mario_data_20250101.csv 2025-10-28 15:21:26.079051
# 2        mario_data_20250101.csv 2025-10-28 15:21:26.079051
# 3        mario_data_20250101.csv 2025-10-28 15:21:26.079051
# 4        mario_data_20250101.csv 2025-10-28 15:21:26.079051
# ...                          ...                        ...
# 47995  mario_data_20250601.jsonl 2025-10-28 15:21:27.251040
# 47996  mario_data_20250601.jsonl 2025-10-28 15:21:27.251040
# 47997  mario_data_20250601.jsonl 2025-10-28 15:21:27.251040
# 47998  mario_data_20250601.jsonl 2025-10-28 15:21:27.251040
# 47999  mario_data_20250601.jsonl 2025-10-28 15:21:27.251040
#
# [48000 rows x 21 columns]

# %%
# validating whether all null values have been filled with a default value
df.isnull().mean()*100
# Out:
# Player Name                     0.0
# Team                            0.0
# World                           0.0
# Vehicle Type                    0.0
# Companion                       0.0
# Kart Racing Rank                0.0
# Platforming Rank                0.0
# Boss Battle Rank                0.0
# Power-Ups Used                  0.0
# Kart Role                       0.0
# Team Points                     0.0
# Lives Lost                      0.0
# Participation in Battle Mode    0.0
# Mushroom Cup Participation      0.0
# Power-Ups Owned                 0.0
# Coins Spent in Toad Town        0.0
# Levels Completed                0.0
# Times Hit by Enemies            0.0
# Primary Game                    0.0
# filename                        0.0
# loadDateTimeStamp               0.0
# dtype: float64

# %%
# removing punctuations from Kart Role
remove_punctuation(df,['Kart Role'])
# Out:
#       Player Name          Team             World     Vehicle Type  \
# 0           Yoshi  Toad Brigade    Yoshi's Island       Comet Bike
# 1          PeachK    GREEN CAPS      Donut Plains  Circuit Special
# 2         Waluigi  Unknown Team    Yoshi's Island       Biddybuggy
# 3           Yoshi  Toad Brigade        Star World       Pipe Frame
# 4      Bowser Jr.    Koopa Clan  Mushroom Kingdom       Pipe Frame
# ...           ...           ...               ...              ...
# 47995    Toadette    Green Caps        Star World           Mach 8
# 47996  Bowser Jr.  Dino Buddies      Donut Plains  Circuit Special
# 47997       Luigi    Green Caps      dONUT pLAINS       Biddybuggy
# 47998    Toadette    Koopa Clan  mUSHROOM kINGDOM  Circuit Special
# 47999    Rosalina  Toad Brigade     Koopa Kingdom           Mach 8
#
#           Companion Kart Racing Rank Platforming Rank Boss Battle Rank  \
# 0         pOLTERPUP                A                A                A
# 1      kOOPA tROOPA                C                A                B
# 2            Goomba                D                A                C
# 3            Goomba                C                D                A
# 4              tOAD                C                C                B
# ...             ...              ...              ...              ...
# 47995          Luma                B                A                S
# 47996  Koopa Troopa                C                C                B
# 47997       Shy Guy                A                D                D
# 47998         Yoshi                B                A                B
# 47999     Polterpup                B                C                C
#
#        Power-Ups Used        Kart Role  ...  Lives Lost  \
# 0                  12          Drifter  ...    0.000000
# 1                  16          Drifter  ...    4.000000
# 2                  26          Blocker  ...    1.000000
# 3                  23          Drifter  ...    5.000000
# 4                  10          Blocker  ...    2.000000
# ...               ...              ...  ...         ...
# 47995               8          Drifter  ...    0.000000
# 47996              13        Speedster  ...    1.083565
# 47997              27          Drifter  ...    4.000000
# 47998               8  Item Specialist  ...    0.000000
# 47999               8          Drifter  ...    2.000000
#
#        Participation in Battle Mode Mushroom Cup Participation  \
# 0                               Yes                         No
# 1                                No                         No
# 2                                No                        Yes
# 3                                No                        Yes
# 4                               Yes                         No
# ...                             ...                        ...
# 47995                            No                        Yes
# 47996                            No                     Unkown
# 47997                           Yes                     Unkown
# 47998                           Yes                        Yes
# 47999                           Yes                         No
#
#                               Power-Ups Owned Coins Spent in Toad Town  \
# 0                               1-Up Mushroom                       64
# 1                       Red Shell, Super Star                      335
# 2                                 Green Shell                      182
# 3                               1-Up Mushroom                      333
# 4         Red Shell, Banana Peel, Fire Flower                      461
# ...                                       ...                      ...
# 47995           1-Up Mushroom, Super Mushroom                      172
# 47996                             Fire Flower                       11
# 47997                              Super Star                      460
# 47998    Super Star, Banana Peel, Green Shell                       82
# 47999  Super Star, Fire Flower, 1-Up Mushroom                      178
#
#        Levels Completed  Times Hit by Enemies  \
# 0                    26                  4.26
# 1                    40                  5.00
# 2                    57                  5.50
# 3                    84                  6.00
# 4                    55                  7.00
# ...                 ...                   ...
# 47995                43                  5.00
# 47996                72                  9.00
# 47997                25                  2.00
# 47998                39                  4.00
# 47999                74                  1.00
#
#                                          Primary Game  \
# 0                          Mario Tennis Aces
# 1                                   Mario Tennis Aces
# 2                                 Mario Kart 8 Deluxe
# 3                                   Super Mario Bros.
# 4                                   Super Mario World
# ...                                               ...
# 47995                               Super Mario Bros.
# 47996                               Super Mario World
# 47997                             Super Mario Odyssey
# 47998                    Mario Kart 8 Deluxe
# 47999                          Mario Party Superstars
#
#                         filename          loadDateTimeStamp
# 0        mario_data_20250101.csv 2025-10-28 15:21:26.079051
# 1        mario_data_20250101.csv 2025-10-28 15:21:26.079051
# 2        mario_data_20250101.csv 2025-10-28 15:21:26.079051
# 3        mario_data_20250101.csv 2025-10-28 15:21:26.079051
# 4        mario_data_20250101.csv 2025-10-28 15:21:26.079051
# ...                          ...                        ...
# 47995  mario_data_20250601.jsonl 2025-10-28 15:21:27.251040
# 47996  mario_data_20250601.jsonl 2025-10-28 15:21:27.251040
# 47997  mario_data_20250601.jsonl 2025-10-28 15:21:27.251040
# 47998  mario_data_20250601.jsonl 2025-10-28 15:21:27.251040
# 47999  mario_data_20250601.jsonl 2025-10-28 15:21:27.251040
#
# [48000 rows x 21 columns]

# %%
# making a dict of expected format/dtype for each column in dataframe
expected_formats ={
	'Player Name': 'string',
	'Team': 'string',
	'Kart Racing Rank': 'string',
	'Mushroom Cup Participation': 'bool',
	'Participation in Battle Mode': 'bool',
	'Platforming Rank': 'string',
	'Boss Battle Rank': 'string',
	'Power-Ups Owned': 'string',
	'Power-Ups Used': 'int32',
    'Kart Role':'string',
	'Team Points': 'int32',
	'Levels Completed': 'int32',
	'Lives Lost': 'int32',
	'Times Hit by Enemies': 'int32',
	'Vehicle Type': 'string',
	'World': 'string',
	'Coins Spent in Toad Town': 'int32',
	'Companion': 'string',
	'Primary Game': 'string',
    'filename':'string',
	'loadDateTimeStamp':'string'
}

# %%
# checking if the columns are in the expected format
check_formats(df,expected_formats=expected_formats)
# Out:
# Below are incorrect formats
# __________________________________________________
# Correct column count: 0
#                          Columns          Actual Expected
# 0                    Player Name          object   string
# 1                           Team          object   string
# 2                          World          object   string
# 3                   Vehicle Type          object   string
# 4                      Companion          object   string
# 5               Kart Racing Rank          object   string
# 6               Platforming Rank          object   string
# 7               Boss Battle Rank          object   string
# 8                 Power-Ups Used           int64    int32
# 9                      Kart Role          object   string
# 10                   Team Points         float64    int32
# 11                    Lives Lost         float64    int32
# 12  Participation in Battle Mode          object     bool
# 13    Mushroom Cup Participation          object     bool
# 14               Power-Ups Owned          object   string
# 15      Coins Spent in Toad Town           int64    int32
# 16              Levels Completed           int64    int32
# 17          Times Hit by Enemies         float64    int32
# 18                  Primary Game          object   string
# 19                      filename          object   string
# 20             loadDateTimeStamp  datetime64[us]   string

# %%
# converting oclumns to expected formats
convert_column_types(df,column_types=expected_formats)
# Out:
#       Player Name          Team             World     Vehicle Type  \
# 0           Yoshi  Toad Brigade    Yoshi's Island       Comet Bike
# 1          PeachK    GREEN CAPS      Donut Plains  Circuit Special
# 2         Waluigi  Unknown Team    Yoshi's Island       Biddybuggy
# 3           Yoshi  Toad Brigade        Star World       Pipe Frame
# 4      Bowser Jr.    Koopa Clan  Mushroom Kingdom       Pipe Frame
# ...           ...           ...               ...              ...
# 47995    Toadette    Green Caps        Star World           Mach 8
# 47996  Bowser Jr.  Dino Buddies      Donut Plains  Circuit Special
# 47997       Luigi    Green Caps      dONUT pLAINS       Biddybuggy
# 47998    Toadette    Koopa Clan  mUSHROOM kINGDOM  Circuit Special
# 47999    Rosalina  Toad Brigade     Koopa Kingdom           Mach 8
#
#           Companion Kart Racing Rank Platforming Rank Boss Battle Rank  \
# 0         pOLTERPUP                A                A                A
# 1      kOOPA tROOPA                C                A                B
# 2            Goomba                D                A                C
# 3            Goomba                C                D                A
# 4              tOAD                C                C                B
# ...             ...              ...              ...              ...
# 47995          Luma                B                A                S
# 47996  Koopa Troopa                C                C                B
# 47997       Shy Guy                A                D                D
# 47998         Yoshi                B                A                B
# 47999     Polterpup                B                C                C
#
#        Power-Ups Used        Kart Role  ...  Lives Lost  \
# 0                  12          Drifter  ...           0
# 1                  16          Drifter  ...           4
# 2                  26          Blocker  ...           1
# 3                  23          Drifter  ...           5
# 4                  10          Blocker  ...           2
# ...               ...              ...  ...         ...
# 47995               8          Drifter  ...           0
# 47996              13        Speedster  ...           1
# 47997              27          Drifter  ...           4
# 47998               8  Item Specialist  ...           0
# 47999               8          Drifter  ...           2
#
#        Participation in Battle Mode  Mushroom Cup Participation  \
# 0                              True                        True
# 1                              True                        True
# 2                              True                        True
# 3                              True                        True
# 4                              True                        True
# ...                             ...                         ...
# 47995                          True                        True
# 47996                          True                        True
# 47997                          True                        True
# 47998                          True                        True
# 47999                          True                        True
#
#                               Power-Ups Owned Coins Spent in Toad Town  \
# 0                               1-Up Mushroom                       64
# 1                       Red Shell, Super Star                      335
# 2                                 Green Shell                      182
# 3                               1-Up Mushroom                      333
# 4         Red Shell, Banana Peel, Fire Flower                      461
# ...                                       ...                      ...
# 47995           1-Up Mushroom, Super Mushroom                      172
# 47996                             Fire Flower                       11
# 47997                              Super Star                      460
# 47998    Super Star, Banana Peel, Green Shell                       82
# 47999  Super Star, Fire Flower, 1-Up Mushroom                      178
#
#        Levels Completed  Times Hit by Enemies  \
# 0                    26                     4
# 1                    40                     5
# 2                    57                     5
# 3                    84                     6
# 4                    55                     7
# ...                 ...                   ...
# 47995                43                     5
# 47996                72                     9
# 47997                25                     2
# 47998                39                     4
# 47999                74                     1
#
#                                          Primary Game  \
# 0                          Mario Tennis Aces
# 1                                   Mario Tennis Aces
# 2                                 Mario Kart 8 Deluxe
# 3                                   Super Mario Bros.
# 4                                   Super Mario World
# ...                                               ...
# 47995                               Super Mario Bros.
# 47996                               Super Mario World
# 47997                             Super Mario Odyssey
# 47998                    Mario Kart 8 Deluxe
# 47999                          Mario Party Superstars
#
#                         filename           loadDateTimeStamp
# 0        mario_data_20250101.csv  2025-10-28 15:21:26.079051
# 1        mario_data_20250101.csv  2025-10-28 15:21:26.079051
# 2        mario_data_20250101.csv  2025-10-28 15:21:26.079051
# 3        mario_data_20250101.csv  2025-10-28 15:21:26.079051
# 4        mario_data_20250101.csv  2025-10-28 15:21:26.079051
# ...                          ...                         ...
# 47995  mario_data_20250601.jsonl  2025-10-28 15:21:27.251040
# 47996  mario_data_20250601.jsonl  2025-10-28 15:21:27.251040
# 47997  mario_data_20250601.jsonl  2025-10-28 15:21:27.251040
# 47998  mario_data_20250601.jsonl  2025-10-28 15:21:27.251040
# 47999  mario_data_20250601.jsonl  2025-10-28 15:21:27.251040
#
# [48000 rows x 21 columns]

# %%
df['Player Name'].dtype
# Out:
# string[python]

# %%
# checking mispellings in Player Name
check_mispelling(df,'Player Name',0.8)
# Out:
#              name1        name2  similarity
# 0           Lduigi       LuigiL      0.8000
# 1           Lduigi       Luiggi      0.8000
# 2           Lduigi       LuigLi      0.8000
# 3           Lduigi       Ludigi      1.0000
# 4           Lduigi       Luuigi      0.8000
# ...            ...          ...         ...
# 21346  Bowser Jr.P  Bowser Jrg.      0.8182
# 21347       Dtaisy       Daiasy      0.8333
# 21348       Dalisy       Daiasy      0.8333
# 21349       Deaisy       Daiasy      0.8333
# 21350       Daiasy       Davisy      0.8333
#
# [21351 rows x 3 columns]

# %%
# making a list of right names in Player Name
rename_values=[
"Mario","Luigi","Peach","Daisy","Yoshi","Toad","Toadette",
"Rosalina","Wario","Waluigi","Bowser","Bowser Jr."
]

# %%
for r in rename_values:
        mask = df['Player Name'].apply(lambda x: check_similarity(r, x) >= 0.8)
        df.loc[mask, 'Player Name'] = r
# renaming values using a boolean mask within the df.loc[] 

check_mispelling(df,'Player Name',0.8)
# Out:
# Empty DataFrame
# Columns: [name1, name2, similarity]
# Index: []

# %%
df['Player Name']
# Out:
# 0             Yoshi
# 1             Peach
# 2           Waluigi
# 3             Yoshi
# 4        Bowser Jr.
#             ...
# 47995      Toadette
# 47996    Bowser Jr.
# 47997         Luigi
# 47998      Toadette
# 47999      Rosalina
# Name: Player Name, Length: 48000, dtype: string

# %%
# Validating for any mispellings
for r in df['Player Name']:
    if r not in rename_values:
        print(r)
# Out:
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# ...
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player
# Unknown Player

# %%
df['Player Name']
# Out:
# 0             Yoshi
# 1             Peach
# 2           Waluigi
# 3             Yoshi
# 4        Bowser Jr.
#             ...
# 47995      Toadette
# 47996    Bowser Jr.
# 47997         Luigi
# 47998      Toadette
# 47999      Rosalina
# Name: Player Name, Length: 48000, dtype: string

# %%
# cleaning trailing and leading white spaces
cols = ['Vehicle Type', 'World', 'Primary Game']
df[cols] = df[cols].apply(lambda x: x.str.strip())

# %%
#validating that no leading or trailing white space exists
for r in df['Primary Game']:
    if r.startswith(" ") or r.endswith(" "):
        print("Space exists")

# %%
for r in df['Vehicle Type']:
    if r.startswith(" ") or r.endswith(" "):
        print("Space exists")

# %%
for r in df['World']:
    if r.startswith(" ") or r.endswith(" "):
        print("Space exists")

# %%
#Capitalizing values
cols = ['Team', 'Companion', 'World']
df[cols] = df[cols].apply(lambda x: x.str.title())

# %%
# Validating capitalized values
df[['Team','Companion','World']]
# Out:
#                Team     Companion             World
# 0      Toad Brigade     Polterpup    Yoshi'S Island
# 1        Green Caps  Koopa Troopa      Donut Plains
# 2      Unknown Team        Goomba    Yoshi'S Island
# 3      Toad Brigade        Goomba        Star World
# 4        Koopa Clan          Toad  Mushroom Kingdom
# ...             ...           ...               ...
# 47995    Green Caps          Luma        Star World
# 47996  Dino Buddies  Koopa Troopa      Donut Plains
# 47997    Green Caps       Shy Guy      Donut Plains
# 47998    Koopa Clan         Yoshi  Mushroom Kingdom
# 47999  Toad Brigade     Polterpup     Koopa Kingdom
#
# [48000 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48000 entries, 0 to 47999
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Player Name                   48000 non-null  string
#  1   Team                          48000 non-null  string
#  2   World                         48000 non-null  string
#  3   Vehicle Type                  48000 non-null  string
#  4   Companion                     48000 non-null  string
#  5   Kart Racing Rank              48000 non-null  string
#  6   Platforming Rank              48000 non-null  string
#  7   Boss Battle Rank              48000 non-null  string
#  8   Power-Ups Used                48000 non-null  int32
#  9   Kart Role                     48000 non-null  string
#  10  Team Points                   48000 non-null  int32
#  11  Lives Lost                    48000 non-null  int32
#  12  Participation in Battle Mode  48000 non-null  bool
#  13  Mushroom Cup Participation    48000 non-null  bool
#  14  Power-Ups Owned               48000 non-null  string
#  15  Coins Spent in Toad Town      48000 non-null  int32
#  16  Levels Completed              48000 non-null  int32
#  17  Times Hit by Enemies          48000 non-null  int32
#  18  Primary Game                  48000 non-null  string
#  19  filename                      48000 non-null  string
#  20  loadDateTimeStamp             48000 non-null  string
# dtypes: bool(2), int32(6), string(13)
# memory usage: 6.0 MB

# %%
# validating formats of columns
check_formats(df,expected_formats=expected_formats)
# Out:
# Validation Complete, no discrepancies

# %% [markdown]
# Saving as parquet file to preserve metadata

# %%
df.to_parquet('./Silver layer/Silver.parquet',index=False)
